# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
def xy_cart_plane(size):
    fig, ax = plt.subplots(figsize=(5, 5))
    ax.set_aspect('equal')
    
    ax.set_xlim([-(size+1), size+1])
    ax.set_ylim([-(size+1), size+1])
    
    ax.spines.left.set_position('zero')
    ax.spines.bottom.set_position('zero')
    ax.spines.right.set_visible(False)
    ax.spines.top.set_visible(False)
    
    ticks = np.arange(-size, size+1)
    ax.set_xticks(ticks[ticks != 0])
    ax.set_yticks(ticks[ticks != 0])
    
    ax.grid(color='grey', linestyle='dotted')
    
    ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
    ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)
    
    ax.set_xlabel('x', size=14, labelpad=-23, x=1.04)
    ax.set_ylabel('y', size=14, labelpad=-23, y=1.04, rotation='horizontal')

    return ax

# %%
# 3
ax = xy_cart_plane(5)

xs = np.arange(-5, 6, .1)
ys = xs**2 + 1
ax.plot(xs, ys)

ys = 2*xs
ax.plot(xs, ys)

ax.scatter(1, 2)

# %%
# 7
print("%.8f"%math.sqrt(4.1))
print("%.8f"%math.sqrt(4.01))
print("%.8f"%math.sqrt(4.001))
print("%.8f"%math.sqrt(4.0001))

print("%.8f"%(0.02484567/0.1))
print("%.8f"%(0.00249844/0.01))
print("%.8f"%(0.00024998/0.001))
print("%.8f"%(0.00002500/0.0001))
# Out:
# 2.02484567
# 2.00249844
# 2.00024998
# 2.00002500
# 0.24845670
# 0.24984400
# 0.24998000
# 0.25000000

# %%
# 9
ax = xy_cart_plane(5)

xs = np.arange(0, 6, .1)
ys = np.sqrt(xs)
ax.plot(xs, ys)

xs = np.arange(-5, 6, .1)
ys = (1/4)*xs + 1
ax.plot(xs, ys)

ax.scatter(4, 2)

# %%
# 13
xs = np.array([-1.05, -1.01, -1.005, -1.001])
ys = 1/xs
secants = (ys - (-1))/(xs - (-1))

print(ys)
print(np.column_stack((xs, ys)))

#print(ys - (-1))
#print(xs - (-1))
#print((ys - (-1))/(xs - (-1)))
print(np.column_stack((xs, ys, secants)))
# Out:
# [-0.95238095 -0.99009901 -0.99502488 -0.999001  ]
# [[-1.05       -0.95238095]
#  [-1.01       -0.99009901]
#  [-1.005      -0.99502488]
#  [-1.001      -0.999001  ]]
# [[-1.05       -0.95238095 -0.95238095]
#  [-1.01       -0.99009901 -0.99009901]
#  [-1.005      -0.99502488 -0.99502488]
#  [-1.001      -0.999001   -0.999001  ]]

# %%
# 15
ax = xy_cart_plane(5)

xs = np.arange(-5, 6, .1)
xs = xs[xs != 0]
ys = 1/xs
ax.plot(xs, ys)

xs = np.arange(-5, 6, .1)
ys = -xs - 2
ax.plot(xs, ys)

ax.scatter(-1, -1)

# %%
ax = xy_cart_plane(5)

xs = np.arange(-5, 6, .1)
ys = xs**2
ax.plot(xs, ys)

ys = 2*xs
ax.plot(xs, ys)

ys = 2*xs - 1
ax.plot(xs, ys)
ax.scatter(1, 1)

ys = 4*xs - 4
ax.plot(xs, ys)
ax.scatter(2, 4)

# %%
ax = xy_cart_plane(5)

xs = np.arange(-5, 6, .1)
ys = xs**2 + 3
ax.plot(xs, ys)

ys = 2*xs
ax.plot(xs, ys)

# %%
ax = xy_cart_plane(5)

xs = np.arange(-5, 6, .1)
ys = xs**2 - 3
ax.plot(xs, ys)

ys = 2*xs
ax.plot(xs, ys)
