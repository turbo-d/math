# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
def xy_cart_plane(size):
    fig, ax = plt.subplots(figsize=(5, 5))
    ax.set_aspect('equal')
    
    ax.set_xlim([-(size+1), size+1])
    ax.set_ylim([-(size+1), size+1])
    
    ax.spines.left.set_position('zero')
    ax.spines.bottom.set_position('zero')
    ax.spines.right.set_visible(False)
    ax.spines.top.set_visible(False)
    
    ticks = np.arange(-size, size+1)
    ax.set_xticks(ticks[ticks != 0])
    ax.set_yticks(ticks[ticks != 0])
    
    ax.grid(color='grey', linestyle='dotted')
    
    ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
    ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)
    
    ax.set_xlabel('x', size=14, labelpad=-23, x=1.04)
    ax.set_ylabel('y', size=14, labelpad=-23, y=1.04, rotation='horizontal')

    return ax

# %%
# 93
xs = np.array([4.1, 4.01, 4.001, 4.0001, 3.9, 3.99, 3.999, 3.9999])
ys = (xs**2 - 16)/(xs - 4)
print(ys)

ax = xy_cart_plane(8)

xs = np.arange(-5, 6, .1)
xs = xs[xs != 4.0]
ys = (xs**2 - 16)/(xs - 4)
ax.plot(xs, ys)
# Out:
# [8.1    8.01   8.001  8.0001 7.9    7.99   7.999  7.9999]

# %%
# 97
print((9.1-9)/(math.sqrt(9.1) - 3))
print((9.01-9)/(math.sqrt(9.01) - 3))
print((9.001-9)/(math.sqrt(9.001) - 3))

print((8.9-9)/(math.sqrt(8.9) - 3))
print((8.99-9)/(math.sqrt(8.99) - 3))
print((8.999-9)/(math.sqrt(8.999) - 3))

print(math.sqrt(9.1))
print(math.sqrt(9.01))
print(math.sqrt(9.001))

print(math.sqrt(8.9))
print(math.sqrt(8.99))
print(math.sqrt(8.999))

print(math.sqrt(9.1) - 3)
print(1/60)
print(math.sqrt(9.01) - 3)
print(1/600)
print(math.sqrt(9.001) - 3)
print(1/6000)
# Out:
# 6.0166206257996295
# 6.001666203961243
# 6.000166662042448
# 5.983286778035196
# 5.998332870113321
# 5.999833328698292
# 3.0166206257996713
# 3.0016662039607267
# 3.000166662037294
# 2.9832867780352594
# 2.99833287011299
# 2.9998333287034464
# 0.016620625799671274
# 0.016666666666666666
# 0.0016662039607266976
# 0.0016666666666666668
# 0.00016666203729398532
# 0.00016666666666666666

# %%
ax = xy_cart_plane(8)

xs = np.arange(-5, 6, .1)
ys = 1/xs**2
ax.plot(xs, ys)

ys = -1/xs**4
ax.plot(xs, ys)

ys = 1/xs**2 - 1/xs**4
ax.plot(xs, ys)

# %%
ax = xy_cart_plane(8)

xs = np.arange(-5, 6, .1)
ys = 1/xs**2
ax.plot(xs, ys)

ys = -1/xs**2
ax.plot(xs, ys)

ys = 1/xs**2 - 1/xs**2
ax.plot(xs, ys)

# %%
# 85
ax = xy_cart_plane(8)

xs = np.arange(-5, 6, .1)
ys = np.sqrt(xs**2 - 6*xs + 3)
ax.plot(xs, ys)
ax.scatter(-2, math.sqrt(19))
# Out:
# /tmp/ipykernel_7263/2276739586.py:5: RuntimeWarning: invalid value encountered in sqrt
#   ys = np.sqrt(xs**2 - 6*xs + 3)

# %%
# 115
ax = xy_cart_plane(8)

xs = np.arange(-5, 3.1, .1)
ys = xs**2
ax.plot(xs, ys)

xs = np.arange(3.1, 6, .1)
ys = xs + 4
ax.plot(xs, ys)

# %%
# 117
ax = xy_cart_plane(8)

xs = np.arange(-5, 2, .1)
ys = xs**2 - 2*xs + 1
ax.plot(xs, ys)

xs = np.arange(2, 6, .1)
ys = 3 - xs
ax.plot(xs, ys)
