# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
def xy_cart_plane(size):
    fig, ax = plt.subplots(figsize=(5, 5))
    ax.set_aspect('equal')
    
    ax.set_xlim([-(size+1), size+1])
    ax.set_ylim([-(size+1), size+1])
    
    ax.spines.left.set_position('zero')
    ax.spines.bottom.set_position('zero')
    ax.spines.right.set_visible(False)
    ax.spines.top.set_visible(False)
    
    ticks = np.arange(-size, size+1)
    ax.set_xticks(ticks[ticks != 0])
    ax.set_yticks(ticks[ticks != 0])
    
    ax.grid(color='grey', linestyle='dotted')
    
    ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
    ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)
    
    ax.set_xlabel('x', size=14, labelpad=-23, x=1.04)
    ax.set_ylabel('y', size=14, labelpad=-23, y=1.04, rotation='horizontal')

    return ax

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
y1s = xs**2
y2s = 2*xs**2
y3s = 0.5*xs**2
ax.plot(xs, y1s)
ax.plot(xs, y2s)
ax.plot(xs, y3s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
y1s = xs**2
y2s = -xs**2
ax.plot(xs, y1s)
ax.plot(xs, y2s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
y1s = xs**2
y2s = xs**2 + 5
y3s = xs**2 - 5
ax.plot(xs, y1s)
ax.plot(xs, y2s)
ax.plot(xs, y3s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
y1s = xs**2
y2s = xs
y3s = xs**2 + xs
ax.plot(xs, y1s)
ax.plot(xs, y2s)
ax.plot(xs, y3s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
y1s = xs**2 + xs
y2s = xs**2 + 2*xs
y3s = xs**2 + 3*xs
y4s = xs**2 + 4*xs
ax.plot(xs, y1s)
ax.plot(xs, y2s)
ax.plot(xs, y3s)
ax.plot(xs, y4s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
y1s = xs**2 + xs
y2s = xs**2 + 0.5*xs
y3s = xs**2 + 0.33*xs
y4s = xs**2 + 0.25*xs
ax.plot(xs, y1s)
ax.plot(xs, y2s)
ax.plot(xs, y3s)
ax.plot(xs, y4s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
y1s = -xs**2 + xs
y2s = -xs**2 + 2*xs
y3s = -xs**2 + 3*xs
y4s = -xs**2 + 4*xs
ax.plot(xs, y1s)
ax.plot(xs, y2s)
ax.plot(xs, y3s)
ax.plot(xs, y4s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
y1s = -xs**2 + xs
y2s = -xs**2 + 0.5*xs
y3s = -xs**2 + 0.33*xs
y4s = -xs**2 + 0.25*xs
ax.plot(xs, y1s)
ax.plot(xs, y2s)
ax.plot(xs, y3s)
ax.plot(xs, y4s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
y1s = xs**2 + -xs
y2s = xs**2 + -2*xs
y3s = xs**2 + -3*xs
y4s = xs**2 + -4*xs
ax.plot(xs, y1s)
ax.plot(xs, y2s)
ax.plot(xs, y3s)
ax.plot(xs, y4s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
y1s = xs**2 + -xs
y2s = xs**2 + -0.5*xs
y3s = xs**2 + -0.33*xs
y4s = xs**2 + -0.25*xs
ax.plot(xs, y1s)
ax.plot(xs, y2s)
ax.plot(xs, y3s)
ax.plot(xs, y4s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
y1s = -xs**2 + -xs
y2s = -xs**2 + -2*xs
y3s = -xs**2 + -3*xs
y4s = -xs**2 + -4*xs
ax.plot(xs, y1s)
ax.plot(xs, y2s)
ax.plot(xs, y3s)
ax.plot(xs, y4s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
y1s = -xs**2 + -xs
y2s = -xs**2 + -0.5*xs
y3s = -xs**2 + -0.33*xs
y4s = -xs**2 + -0.25*xs
ax.plot(xs, y1s)
ax.plot(xs, y2s)
ax.plot(xs, y3s)
ax.plot(xs, y4s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
ys = xs**2
y1s = xs**2 + xs
y2s = xs**2 + -xs
ax.plot(xs, ys)
ax.plot(xs, y1s)
ax.plot(xs, y2s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
ys = -xs**2
y1s = -xs**2 + xs
y2s = -xs**2 + -xs
ax.plot(xs, ys)
ax.plot(xs, y1s)
ax.plot(xs, y2s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
ys = xs**2 + 1
ax.plot(xs, ys)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
ys = xs**2 + 6*xs + 9
ax.plot(xs, ys)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
ys = xs**2 + xs
ax.plot(xs, ys)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
ys = xs**(1/2)
ax.plot(xs, ys)
# Out:
# /tmp/ipykernel_100/1549680783.py:3: RuntimeWarning: invalid value encountered in sqrt
#   ys = xs**(1/2)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
ys = -2*xs**2 + 280*xs - 1000
ax.plot(xs, ys)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
ys = xs**2

#y1s = (xs - 1)**2
y1s = xs**2 - 2*xs + 1

#y2s = (xs - 2)**2
y2s = xs**2 - 4*xs + 4

#y3s = (xs - 3)**2
y3s = xs**2 - 6*xs + 9

ax.plot(xs, ys)
#ax.plot(xs, y1s)
#ax.plot(xs, y2s)
ax.plot(xs, y3s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)
ys = xs**2

#y1s = (xs + 1)**2
y1s = xs**2 + 2*xs + 1

#y2s = (xs - 2)**2
y2s = xs**2 + 4*xs + 4

#y3s = (xs - 3)**2
y3s = xs**2 + 6*xs + 9

ax.plot(xs, ys)
#ax.plot(xs, y1s)
#ax.plot(xs, y2s)
ax.plot(xs, y3s)

# %%
ax = xy_cart_plane(10)
xs = np.arange(-5,6, .05)

ys = xs**2
ax.plot(xs, ys)

#y1s = (xs - 1)**2
y1s = xs**2 - 2*xs + 1
ax.plot(xs, y1s)

y2s = xs**2 + 1
ax.plot(xs, y2s)

y3s = xs**2 - 2*xs
ax.plot(xs, y3s)
