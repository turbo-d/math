# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# %%
def xy_cart(xs, ys, size, connect_points):
    fig, ax = plt.subplots(figsize=(5, 5))
    ax.set_aspect('equal')
    
    ax.set_xlim([-(size+1), size+1])
    ax.set_ylim([-(size+1), size+1])
    
    ax.spines.left.set_position('zero')
    ax.spines.bottom.set_position('zero')
    ax.spines.right.set_visible(False)
    ax.spines.top.set_visible(False)
    
    ticks = np.arange(-size, size+1)
    ax.set_xticks(ticks[ticks != 0])
    ax.set_yticks(ticks[ticks != 0])
    
    ax.grid(color='grey', linestyle='dotted')
    
    ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
    ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)
    
    ax.set_xlabel('x', size=14, labelpad=-23, x=1.04)
    ax.set_ylabel('y', size=14, labelpad=-23, y=1.04, rotation='horizontal')

    if connect_points:
        ax.plot(xs, ys)
        return
        
    ax.scatter(xs, ys)

# %%
# 21
dist = math.sqrt((41-19)**2 + (71-12)**2)
dist
# Out:
# 62.96824596572466

# %%
# 31
xs = [-1, 0, 2]
ys = [2, 4, 1]
xy_cart(xs, ys, 5, False)

# %%
# 35
def f(x):
    return x/3 + 2

xs = np.arange(-5, 6, 2)
ys = f(xs)

xy_cart(xs, ys, 5, True)

# %%
# 37
def f(x):
    return x/2 + 3/2

xs = np.arange(-5, 6, 2)
ys = f(xs)

xy_cart(xs, ys, 5, True)

# %%
# 39
def f(x):
    return x/2 -4

xs = np.arange(-8, 9, 2)
ys = f(xs)

xy_cart(xs, ys, 8, True)

# %%
# 41
def f(x):
    return -2*x/3 + 2

xs = np.arange(-5, 6, 2)
ys = f(xs)

xy_cart(xs, ys, 5, True)

# %%
# 43
2*math.sqrt(17)
# Out:
# 8.246211251235321

# %%
# 49
def f(x):
    return 3*x/4 - 2

xs = np.arange(-5, 6, 2)
ys = f(xs)

xy_cart(xs, ys, 5, True)
